# %% [markdown]
# # algorithm
#
# This notebook describes the algorithm.

# %%
import sys  

reload(sys)  
sys.setdefaultencoding('utf8')

# %%
import numpy as np

# %%
import pandas as pd
import sqlalchemy
import connect_aws_db as cadb

# %%
engine = cadb.connect_aws_db(write_unicode=True)

# %%
conn = engine.connect()

# %%
cmd = 'SELECT * FROM yelp_reviews'

# %%
yelp_reviews = pd.read_sql(cmd, engine)

# %%
yelp_reviews.head(3)
# Out:
#    rev_id             business_id yelp_review_date          yelp_review_id  \
# 0       1  bWWrrsPWuoHuAGUCgH8Tyg       2007-10-28  TMiAAS5RB-P5EwXs7B9aBw
# 1       2  bWWrrsPWuoHuAGUCgH8Tyg       2008-01-05  F78V6FFuUr9pawcok4YRyg
# 2       3  bWWrrsPWuoHuAGUCgH8Tyg       2008-03-08  g6vMKao00XSECOd6JtKPEA
#
#    review_rating                                        review_text  \
# 0              4  I stayed at the hotel for several months durin...
# 1              5  I have been coming to Pittsburgh for quite a w...
# 2              4  This is a very good hotel and with a corporate...
#
#                   user_id
# 0  ZqoMKTrJOtyYZOcvP8rTUA
# 1  uiMTavYKLw9hxskV4xB2tg
# 2  TckShYnQa0eD3WQxdoE3GQ

# %%
cmd = 'SELECT * FROM bf_reviews'

# %%
bf_reviews = pd.read_sql(cmd, engine)

# %%
bf_reviews
# Out:
#    review_id hotel_id business_id  user_id  \
# 0          1        0        None        0
# 1          2        1        None        0
# 2          3        1        None        0
# 3          4        1        None        0
# 4          5        1        None        0
# 5          6        1        None        0
# 6          7        1        None        0
# 7          8        2        None        0
#
#                              username                     review_title  \
# 0  \nMarti Ackermann\nin Tucson, AZ\n         Pointe Hilton Squaw Peak
# 1               \nJen\nin Vancouver\n             Great place to stay!
# 2       \nJody\nin Sierra Vista, AZ\n                 Awesome Staff!!
# 3         \nKristi\nin Henderson NV\n                Very dog friendly
# 4     \nChristopher\nin Los Angeles\n  All around great place to stay.
# 5                 \nDave\nin Sedona\n  Management and customer service
# 6    \nTeri\nin Southern California\n                 Bad Experience.
# 7              \nemma\nin park city\n                      no dog area
#
#    review_rating                                        review_text
# 0              5  Really nice property. Great walking areas for ...
# 1              5  We've stayed at this La Quinta several times w...
# 2              5  This place was awesome!! The entire staff was ...
# 3              5  We've stayed at this hotel two times with our ...
# 4              4  My room while a bit small was very clean and t...
# 5              3  The big gentleman who manages the front desk i...
# 6              1  I was driving from So Cal to Houston, TX for t...
# 7              2  the hotel was fine but it is all hard scape ar...

# %%
cmd = 'SELECT * FROM bf_hotels'

# %%
bf_hotels = pd.read_sql(cmd, engine)

# %%
bf_hotels
# Out:
#    hotel_id                                          hotel_url  \
# 0         1  http://www.bringfido.com/lodging/city/phoenix_...
# 1         2  http://www.bringfido.com/lodging/city/phoenix_...
# 2         3  http://www.bringfido.com/lodging/city/phoenix_...
# 3         4  http://www.bringfido.com/lodging/city/phoenix_...
# 4         5  http://www.bringfido.com/lodging/city/phoenix_...
# 5         6  http://www.bringfido.com/lodging/city/phoenix_...
# 6         7  http://www.bringfido.com/lodging/city/phoenix_...
# 7         8  http://www.bringfido.com/lodging/city/phoenix_...
#
#                         hotel_name             hotel_address hotel_city  \
# 0  Pointe Hilton Squaw Peak Resort  \n7677 North 16th Street    Phoenix
# 1    La Quinta Inn Phoenix Arcadia        \n4727 E Thomas Rd    Phoenix
# 2    La Quinta Inn Phoenix Arcadia        \n4727 E Thomas Rd    Phoenix
# 3    La Quinta Inn Phoenix Arcadia        \n4727 E Thomas Rd    Phoenix
# 4    La Quinta Inn Phoenix Arcadia        \n4727 E Thomas Rd    Phoenix
# 5    La Quinta Inn Phoenix Arcadia        \n4727 E Thomas Rd    Phoenix
# 6    La Quinta Inn Phoenix Arcadia        \n4727 E Thomas Rd    Phoenix
# 7      La Quinta Inn Phoenix North       \n2510 WGreenway Rd    Phoenix
#
#   hotel_state  hotel_rating  hotel_latitude  hotel_longitude business_id  \
# 0          AZ             5               0                0        None
# 1          AZ             4               0                0        None
# 2          AZ             4               0                0        None
# 3          AZ             4               0                0        None
# 4          AZ             4               0                0        None
# 5          AZ             4               0                0        None
# 6          AZ             4               0                0        None
# 7          AZ             2               0                0        None
#
#    review_count
# 0             1
# 1             6
# 2             6
# 3             6
# 4             6
# 5             6
# 6             6
# 7             1

# %%
cmd = 'SELECT * FROM yelp_hotels'

# %%
yelp_hotels = pd.read_sql(cmd, engine)

# %%
yelp_hotels[yelp_hotels['hotel_name'].str.contains('Squaw')]
# Out:
#     hotel_id                       hotel_name  hotel_rating hotel_city  \
# 61        62  Pointe Hilton Squaw Peak Resort           3.5    Phoenix
#
#    hotel_state  hotel_latitude  hotel_longitude  review_count  \
# 61          AZ         33.5478         -112.047           160
#
#                         hotel_address             business_id dogs_allowed
# 61  7677 N 16th St\nPhoenix, AZ 85020  N1xMSUfv1GmfHGa9a3VuJw            1

# %%
bf_hotels['business_id'][0] = 'N1xMSUfv1GmfHGa9a3VuJw'

# %%
bf_hotels
# Out:
#    hotel_id                                          hotel_url  \
# 0         1  http://www.bringfido.com/lodging/city/phoenix_...
# 1         2  http://www.bringfido.com/lodging/city/phoenix_...
# 2         3  http://www.bringfido.com/lodging/city/phoenix_...
# 3         4  http://www.bringfido.com/lodging/city/phoenix_...
# 4         5  http://www.bringfido.com/lodging/city/phoenix_...
# 5         6  http://www.bringfido.com/lodging/city/phoenix_...
# 6         7  http://www.bringfido.com/lodging/city/phoenix_...
# 7         8  http://www.bringfido.com/lodging/city/phoenix_...
#
#                         hotel_name             hotel_address hotel_city  \
# 0  Pointe Hilton Squaw Peak Resort  \n7677 North 16th Street    Phoenix
# 1    La Quinta Inn Phoenix Arcadia        \n4727 E Thomas Rd    Phoenix
# 2    La Quinta Inn Phoenix Arcadia        \n4727 E Thomas Rd    Phoenix
# 3    La Quinta Inn Phoenix Arcadia        \n4727 E Thomas Rd    Phoenix
# 4    La Quinta Inn Phoenix Arcadia        \n4727 E Thomas Rd    Phoenix
# 5    La Quinta Inn Phoenix Arcadia        \n4727 E Thomas Rd    Phoenix
# 6    La Quinta Inn Phoenix Arcadia        \n4727 E Thomas Rd    Phoenix
# 7      La Quinta Inn Phoenix North       \n2510 WGreenway Rd    Phoenix
#
#   hotel_state  hotel_rating  hotel_latitude  hotel_longitude  \
# 0          AZ             5               0                0
# 1          AZ             4               0                0
# 2          AZ             4               0                0
# 3          AZ             4               0                0
# 4          AZ             4               0                0
# 5          AZ             4               0                0
# 6          AZ             4               0                0
# 7          AZ             2               0                0
#
#               business_id  review_count
# 0  N1xMSUfv1GmfHGa9a3VuJw             1
# 1                    None             6
# 2                    None             6
# 3                    None             6
# 4                    None             6
# 5                    None             6
# 6                    None             6
# 7                    None             1

# %%
cmd = "DROP TABLE bf_hotels"
result = conn.execute(cmd)

# %%
cmd = """
        CREATE TABLE bf_hotels
        (
        hotel_id MEDIUMINT AUTO_INCREMENT,
        hotel_url VARCHAR(512),
        hotel_name VARCHAR(512),
        hotel_address VARCHAR(1024),
        hotel_city VARCHAR(512),
        hotel_state VARCHAR(32),
        hotel_rating INT,
        hotel_latitude FLOAT,
        hotel_longitude FLOAT,
        business_id VARCHAR(256),
        review_count MEDIUMINT,
        PRIMARY KEY (hotel_id)
        )
        """

# %%
result = conn.execute(cmd)

# %%
bf_hotels.to_sql('bf_hotels', engine, if_exists='append', index=False)

# %%
yelp = pd.merge(yelp_hotels, yelp_reviews, on='business_id', how='inner')

# %%
yelp
# Out:
#       hotel_id                                      hotel_name  hotel_rating  \
# 0            1        The Westin Convention Center, Pittsburgh           3.5
# 1            1        The Westin Convention Center, Pittsburgh           3.5
# 2            1        The Westin Convention Center, Pittsburgh           3.5
# 3            1        The Westin Convention Center, Pittsburgh           3.5
# 4            1        The Westin Convention Center, Pittsburgh           3.5
# 5            1        The Westin Convention Center, Pittsburgh           3.5
# 6            1        The Westin Convention Center, Pittsburgh           3.5
# 7            1        The Westin Convention Center, Pittsburgh           3.5
# 8            1        The Westin Convention Center, Pittsburgh           3.5
# 9            1        The Westin Convention Center, Pittsburgh           3.5
# 10           1        The Westin Convention Center, Pittsburgh           3.5
# 11           1        The Westin Convention Center, Pittsburgh           3.5
# 12           1        The Westin Convention Center, Pittsburgh           3.5
# 13           1        The Westin Convention Center, Pittsburgh           3.5
# 14           1        The Westin Convention Center, Pittsburgh           3.5
# 15           1        The Westin Convention Center, Pittsburgh           3.5
# 16           1        The Westin Convention Center, Pittsburgh           3.5
# 17           1        The Westin Convention Center, Pittsburgh           3.5
# 18           1        The Westin Convention Center, Pittsburgh           3.5
# 19           1        The Westin Convention Center, Pittsburgh           3.5
# 20           1        The Westin Convention Center, Pittsburgh           3.5
# 21           1        The Westin Convention Center, Pittsburgh           3.5
# 22           1        The Westin Convention Center, Pittsburgh           3.5
# 23           1        The Westin Convention Center, Pittsburgh           3.5
# 24           1        The Westin Convention Center, Pittsburgh           3.5
# 25           1        The Westin Convention Center, Pittsburgh           3.5
# 26           1        The Westin Convention Center, Pittsburgh           3.5
# 27           1        The Westin Convention Center, Pittsburgh           3.5
# 28           1        The Westin Convention Center, Pittsburgh           3.5
# 6238              Kaiserstraße 231\n76133 Karlsruhe  O_8KPbCJpKSuFeqgmY0rHQ
# 6239              Kaiserstraße 231\n76133 Karlsruhe  O_8KPbCJpKSuFeqgmY0rHQ
# 6240              Kaiserstraße 231\n76133 Karlsruhe  O_8KPbCJpKSuFeqgmY0rHQ
# 6241         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6242         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6243         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6244         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6245         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6246         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6247         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6248         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6249         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6250         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6251         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6252         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6253         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6254         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6255         10831 South 51st St\nPhoenix, AZ 85044  q54q6eLD9qsoKQFMu4IM_Q
# 6256             225 E Apache Blvd\nTempe, AZ 85281  LcqzL_4UKl0ETqRUJKA_7Q
# 6257             225 E Apache Blvd\nTempe, AZ 85281  LcqzL_4UKl0ETqRUJKA_7Q
# 6258             225 E Apache Blvd\nTempe, AZ 85281  LcqzL_4UKl0ETqRUJKA_7Q
# 6259             225 E Apache Blvd\nTempe, AZ 85281  LcqzL_4UKl0ETqRUJKA_7Q
# 6260             225 E Apache Blvd\nTempe, AZ 85281  LcqzL_4UKl0ETqRUJKA_7Q
# 6261             225 E Apache Blvd\nTempe, AZ 85281  LcqzL_4UKl0ETqRUJKA_7Q
# 6262             225 E Apache Blvd\nTempe, AZ 85281  LcqzL_4UKl0ETqRUJKA_7Q
#
#      dogs_allowed  rev_id yelp_review_date          yelp_review_id  \
# 0               1       1       2007-10-28  TMiAAS5RB-P5EwXs7B9aBw
# 1               1       2       2008-01-05  F78V6FFuUr9pawcok4YRyg
# 2               1       3       2008-03-08  g6vMKao00XSECOd6JtKPEA
# 3               1       4       2008-03-29  PNS9z4aFDbfhpIsHCfNvNg
# 4               1       5       2008-07-07  gyYXmBwP3jSinLuXtuGRuQ
# 5               1       6       2008-11-22  fmL0UvXQgPwN6mO3HEs1jA
# 6               1       7       2009-04-06  UcdYzG9E_xDqgIWhZEjz5Q
# 7               1       8       2009-07-20  KE9THkNNQ0p9K5KGLSc_9Q
# 8               1       9       2009-11-27  aha23u_Yxh1d8C8ZHfDqTA
# 9               1      10       2010-02-05  qZZRuL_W7M65BWchFXED7Q
# 10              1      11       2010-02-17  azlZcBwgiMp2Y8qKgzE5Cg
# 11              1      12       2010-04-14  J2UwiemTJAfkLrgWceUqag
# 12              1      13       2010-04-21  kfChs8_dyEqq475hsDKPQA
# 13              1      14       2010-05-30  61bFTdo6emrWgppN-Sj5-g
# 14              1      15       2010-06-30  dZGoTXN8e1F7aTzAnVzKWQ
# 15              1      16       2010-07-01  vI2DZpdYO8oVS_eauZKV0g
# 16              1      17       2010-07-14  xIHlfW7zCLFrg8wVSd4SgA
# 17              1      18       2010-07-15  0clkq-V3Iyul-9s15ZvbrQ
# 18              1      19       2010-08-25  CBf72qy6We-q-uGtx7tdIw
# 19              1      20       2010-11-25  _CabZZXadsNZOhnZHX6Zmw
# 20              1      21       2010-11-26  5lr09o6VQExE75vj0abUlQ
# 21              1      22       2011-09-01  wtxvKEI5tSE696HMj38SUw
# 22              1      23       2011-10-18  PyzIu4YSLHAGJFKXjv1CmQ
# 23              1      24       2011-11-04  SaEKmSHe8ngDSpxAkVBuYg
# 24              1      25       2011-11-09  zyRWBncq180ghTxss4cUlA
# 25              1      26       2011-11-15  EAxJRvftO9BZ4-4EnGB-YA
# 26              1      27       2011-11-20  jQUff39wWMo-gnVW_36eog
# 27              1      28       2012-01-21  iz-xyIwJma7EQUafboyvWQ
# 28              1      29       2012-01-23  0D_5c5OflekPjtz5Hnqu4w
# 29              1      30       2012-01-26  d6dPiKeNlGdWiSjkcxjqlg
# ...           ...     ...              ...                     ...
# 6233            1    6234       2007-07-10  qwEXA7sqKIOSP63Mt0cO7Q
# 6234            1    6235       2010-01-10  igNAaV_4Bio9zzidDs3o0A
# 6235            1    6236       2010-07-23  --b9S77-6ODn_OgLIOvoGw
# 6236            1    6237       2012-08-21  M27GP0zBXBF27SONegmRkw
# 6237            1    6238       2012-09-07  kkhOlAV-_gjcmXlRVrblFQ
# 6238            1    6239       2012-12-31  FbTDwSjAhwthodIBqIb2hQ
# 6239            1    6240       2013-06-12  KtnUIz0TO2qDIzY69GLSLw
# 6240            1    6241       2013-08-07  G7XtVeQckp6U1bfwErRcVw
# 6241            1    6242       2014-05-15  lBnmMdIMp_LXDadOWOcdcA
# 6242            1    6243       2014-06-11  IICFqs51iZbzQBEUkVQ8cQ
# 6243            1    6244       2014-06-13  C3PoIirFBuCc4bS4CX3XEg
# 6244            1    6245       2014-06-29  en3ujvfysz0G9YaHa-9xGA
# 6245            1    6246       2014-08-01  IaevvwSL27ffmEkz3mwILQ
# 6246            1    6247       2014-08-07  3k4IB_u0lgfVB7wGa1IAig
# 6247            1    6248       2014-08-25  VsletHMPCX9kEs9-aC1VFg
# 6248            1    6249       2014-10-10  YZJogahne3uhmWemCtqx1Q
# 6249            1    6250       2014-10-27  zQoxGfzangiyK6LJOoqHLg
# 6250            1    6251       2014-11-04  9Vl3agFSMRYVGD6gdMICyg
# 6251            1    6252       2014-11-04  p4EyppNQ-5TaAPtKLD_6Rg
# 6252            1    6253       2014-11-10  ikQV77Hijc6kW7bCrEkP3Q
# 6253            1    6254       2014-11-16  zz9mEgAmakO43soXtfhCoA
# 6254            1    6255       2015-01-02  c6zqQM_0O7cTmtj7TEx2FA
# 6255            1    6256       2015-01-07  Dt6FjzbCesA0Y9DcEH0JFQ
# 6256            1    6257       2014-11-03  IYvg2HqZLWw3jUwjBzAIbg
# 6257            1    6258       2014-11-09  OiLIvdRij6CGlCrrkqdpnQ
# 6258            1    6259       2014-11-11  qhYNKyTwzarNj7vEynYg1g
# 6259            1    6260       2014-11-16  hg4OivGTzGG468u202HmeA
# 6260            1    6261       2014-12-16  DvpcMyWitj-d3u3QSca6lw
# 6261            1    6262       2014-12-19  kcy6XndboL99H73SkDjOzw
# 6262            1    6263       2014-12-27  STzppCFcPUJm4mepGWVdaA
#
#       review_rating                                        review_text  \
# 0                 4  I stayed at the hotel for several months durin...
# 1                 5  I have been coming to Pittsburgh for quite a w...
# 2                 4  This is a very good hotel and with a corporate...
# 3                 4  i got upgraded to a junior suite, and then aga...
# 4                 5  This is a fantastic hotel.  I went to a conven...
# 5                 3  Being a Southern California boy, I was not par...
# 6                 4  I was in town for an interview and didn't pay ...
# 7                 4  The Westin is a great place to stay.  The beds...
# 8                 4  I really enjoyed my stay at the Westin.  Durin...
# 9                 2  When I think of Westins, I think of business-c...
# 10                2  Location is ok for the downtown area. Not too ...
# 11                4  Great location, close to the convention center...
# 12                3  I was expecting a high quality hotel from the ...
# 13                3  I do not understand the new obsession with hot...
# 14                4  I stayed at this hotel while attending a conve...
# 15                4  Overall a solid hotel, I've stayed here 4 of t...
# 16                4  Although I was only there one night I was pret...
# 17                4  The hotel is kept clean and the room rates wer...
# 18                4  The Westin  convention Center is located downt...
# 19                3  I stayed here for a 2 day conference and was n...
# 20                3  The service was good. Tony the shuttle driver ...
# 21                3  I usually look for the westin whenever im trav...
# 22                4  I've stayed at this Westin a few days a week f...
# 23                4  Stayed here for a convention next door, mostly...
# 24                4  I've been here for several events over the pas...
# 25                2  We got this hotel room via Hotwire at a great ...
# 26                4  I stayed here this past weekend for a conferen...
# 27                4  I travel every week for work and was always a ...
# 28                2  My boyfriend and I stayed here for a long week...
# 29                3  I stayed here a week ago and was not impressed...
# ...             ...                                                ...
# 6233              4  Ups, ich hatte noch keinen Beitrag zum Basisla...
# 6234              5  Klasse Laden mit viel Auswahl und tollem Servi...
# 6235              5  Klasse Laden mit viel Auswahl und tollem Servi...
# 6236              4  Toller Laden mit professioneller und guter Ber...
# 6237              4  Früher in der Waldstraße, jetzt in der Kaisers...
# 6238              5  Das Basislager ist für Outdoor-,Trekking- und ...
# 6239              4  Große Auswahl, ganz klar dem Outdoor-Freund ge...
# 6240              4  Große Auswahl, ganz klar... dem Outdoor-Freund...
# 6241              4  1. No Acknowledgement at the front desk, nice ...
# 6242              1  I came here last weekend for Power 98.3's Revi...
# 6243              5  Where to begin. \n1. Excellent customer servic...
# 6244              5  Great room! Friendly check in! Got a great rat...
# 6245              4  My experience with this hotel was very differe...
# 6246              4  My room was beautiful ~ spacious, comfortable,...
# 6247              5  My recent stay at South Mountain was Fantastic...
# 6248              1  I don't usually write reviews, but my experien...
# 6249              2  Not the greatest hotel experience I've had. I ...
# 6250              5  I can't express it any other way but WOW I LOV...
# 6251              1  I can't believe my experience here..\n\nTo kee...
# 6252              4  Nice hotel in a central locale near the 10. St...
# 6253              1  This place is completely useless, the staff is...
# 6254              1  This hotel was a 3.5 star on Priceline but I'm...
# 6255              4  This is an affordable, clean updated hotel loc...
# 6256              5  Listen, I party. A lot.  And I don't drink and...
# 6257              5  Amazing Staff.  I was an ASU grad.  Had to sta...
# 6258              5  Only one word comes to mind when I think about...
# 6259              5  I have 2 words for you, Freaking Fantastic!!!\...
# 6260              5  Large, clean rooms.  Very comfortable beds.  F...
# 6261              4  Awesome place to stay when near ASU. Friendly ...
# 6262              1  I only left one star, because there wasn't an ...
#
#                      user_id
# 0     ZqoMKTrJOtyYZOcvP8rTUA
# 1     uiMTavYKLw9hxskV4xB2tg
# 2     TckShYnQa0eD3WQxdoE3GQ
# 3     MquuHY8ar78FUjkbcmVyPw
# 4     pzhiDEp8EFltFmdldP9Oow
# 5     EV4u-Ct9a0Yl7ecwAffccw
# 6     5SLDX3bXcRP52QlStIcYLg
# 7     sOnj2ToEH_q-pajhmHsI4w
# 8     YqhqFM2Q400HXFy0L6QL2g
# 9     q_jNEFRQfYunkJlqEITSHw
# 10    Jhq8AsZccqAWvfw6Dq2fWA
# 11    EKOf7h3O-5KyTtiC1xi13w
# 12    jRPv3y6eejhaWicnkP_kJQ
# 13    J-52g3nkjcOV4wq5oTRXUA
# 14    yCS_hr75GmRXCFgadFHtuA
# 15    FiVUmdW-pk6dyQeD-eqarA
# 16    aZljc_FO-XUnA9VaFlXzEQ
# 17    DfewvXBVh68PdGWs4cT5YQ
# 18    qmUczLelWz2fZIp9_1ehJQ
# 19    ncITKl6ATrc5JgXUni97RA
# 20    xZgzmgY82OEAKnwyVp8WJQ
# 21    SchRz_Vt0_xbp2FUNPz5CQ
# 22    vMcID1kC8I4OAL6HA3IP1Q
# 23    s-hjAU_t1mKY9YMtV-YX2A
# 24    D1G8W0SgCbsKTv7cAqKcNg
# 25    zEdyUGMP1J2BdYQo0B-CMw
# 26    pk9DbYTH3mrDRmmjvMq72w
# 27    1Kup1mjV8uox4wWeIDEjQQ
# 28    juzL-AXKUceVFi2MXIPZ5Q
# 29    a0UPEnAIdT14_34nMU8B9A
# ...                      ...
# 6233  2tQfo3VoswnM-jR621X9oA
# 6234  c5baNLWzuQG1rm1wigyFuQ
# 6235  c5baNLWzuQG1rm1wigyFuQ
# 6236  yu8-rz4bMadUs6c0ajwq6w
# 6237  gjlVdzfaVpMdr_z4RlxX3w
# 6238  TRa_00SLt8yVbd1T3nLZ7g
# 6239  ya-3mYHRqnMU6IgsUMyOCg
# 6240  ya-3mYHRqnMU6IgsUMyOCg
# 6241  aHYQrxjDmXiTBP4WLP4sIA
# 6242  wRsrr3_qbZIj_-zbKspfpw
# 6243  v6TyhMR82EUchb8Ye7co4A
# 6244  _0dxI24jNnYvg7lUBNcFKg
# 6245  EBrJbXjKMTFGeyEb9YPyrA
# 6246  VKpjvz68qBWdUu08F62VPA
# 6247  aHYQrxjDmXiTBP4WLP4sIA
# 6248  aRppvZNrmBPoESnaXAkDuw
# 6249  9iyat9IlO_EnWU97EujWgQ
# 6250  Zg2pzfamQGsKYm-ja2q81g
# 6251  WJEmeL_3vHIOLepEwd2lrQ
# 6252  pfVTG-fFaQ1wuLqNuC8wvQ
# 6253  DrO4IJz1jUFVizPatBEcxw
# 6254  jIpvyIS3s31MbthRGkbNyQ
# 6255  zGw7Br-XlmrfeCZx6IjFQw
# 6256  T6eB-L_sgxpRkS739xQQbQ
# 6257  _pp_l1ZYznN2OEt7yfCTOg
# 6258  doWD86Iw7B8BVOaqtAC4tA
# 6259  UQlBrZ6ho91lynwdDu8WVQ
# 6260  TNFm9ll5sZwa3SGbIqWKIw
# 6261  BMcjqDKeU0R9ut8OzvumEA
# 6262  9wDMNsoVkMeZTNdLmRNIFQ
#
# [6263 rows x 17 columns]

# %%
len(yelp)
# Out:
# 6263

# %%
yelp_phoenix = yelp[yelp['hotel_city'] == 'Phoenix']

# %%
len(yelp_phoenix)
# Out:
# 1120

# %%
yelp_dog_review = yelp_phoenix[yelp_phoenix['review_text'].str.contains('dog')].copy()

# %%
len(yelp_dog_review)
# Out:
# 36

# %%
np.unique(yelp_dog_review['hotel_id'])
# Out:
# array([  8,  10,  11,  35,  36,  55,  61,  62,  79,  81,  89, 106, 117, 118])

# %%
average_ratings = [np.mean(yelp_phoenix[yelp_phoenix['hotel_id'] == hotel_id]['hotel_rating'].values) for hotel_id in np.unique(yelp_dog_review['hotel_id'])]

# %%
average_dog_ratings = [np.mean(yelp_dog_review[yelp_dog_review['hotel_id'] == hotel_id]['hotel_rating'].values) for hotel_id in np.unique(yelp_dog_review['hotel_id'])]

# %%
average_dog_ratings
# Out:
# [3.0, 3.5, 3.0, 2.5, 3.5, 3.0, 3.5, 3.5, 3.0, 4.0, 3.5, 4.0, 4.5, 1.5]

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = 12.94, 8
fig, ax = plt.subplots(1, 1)
ax.plot(average_ratings, average_dog_ratings, 'o', color='#B2CFEC', ms=10)
ax.set_xlabel('All Ratings')
ax.set_ylabel('Dog Ratings')
ax.set_xlim([0, 5.5])
ax.set_ylim([0, 5.5])
plt.savefig('/Users/matt/Desktop/rating_comparison.png', dpi=144)

# %%
print(len(bf_reviews))
print(len(yelp_phoenix))
print(len(yelp_dog_review))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
bars = ax1.bar(range(1,4), range(1,4), color='blue', edgecolor='black')
