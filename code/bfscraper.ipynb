# %% [markdown]
# # bfscraper
#
# a notebook for scraping data from bringfido

# %%
from bs4 import BeautifulSoup
import urllib.request

# %%
url="http://www.bringfido.com/lodging/city/new_haven_ct_us/"

# %%
try:
    from urllib.request import Request, urlopen  # Python 3
except:
    from urllib2 import Request, urlopen  # Python 2

q = Request(url)
q.add_header('User-Agent', 'Mozilla/5.0')
page = urlopen(q).read()

#print(page)

# %%
soup = BeautifulSoup(page)

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/site_media/css/screen.css" rel="stylesheet" type="text/css"/>
# <meta content="app-id=682820712" name="apple-itunes-app"/>
# <link href="/site_media/yui/container/assets/skins/sam/container.css" rel="stylesheet" type="text/css"/>
# <link href="/site_media/yui/calendar/assets/skins/sam/calendar.css" rel="stylesheet" type="text/css"/>
# <link href="/site_media/yui/autocomplete/assets/skins/sam/autocomplete.css" rel="stylesheet" type="text/css"/>
# <link href="/site_media/images/favicon.ico" rel="icon" type="image/png"/>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.8.3/jquery.min.js" type="text/javascript"></script>
# <script src="/site_media/yui/yahoo-dom-event/yahoo-dom-event.js" type="text/javascript"></script>
# <script src="/site_media/yui/connection/connection-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/container/container-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/calendar/calendar-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/autocomplete/autocomplete-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/dragdrop/dragdrop-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/slider/slider-min.js" type="text/javascript"></script>
# <script src="/site_media/js/utils.js" type="text/javascript"></script>
# <script src="/site_media/js/autocomplete.js" type="text/javascript"></script>
# <script src="/site_media/js/cal.js" type="text/javascript"></script>
# <script src="/site_media/js/tab_search.js" type="text/javascript"></script>
# <script src="/site_media/js/default_text.js" type="text/javascript"></script>
# <script src="/site_media/js/alert.js" type="text/javascript"></script>
# <script src="/site_media/yui/yahoo/yahoo-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/json/json-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/dragdrop/dragdrop-min.js" type="text/javascript"></script>
# <link href="/site_media/yui/logger/assets/skins/sam/logger.css" rel="stylesheet" type="text/css"/>
# <script src="/site_media/yui/yahoo-dom-event/yahoo-dom-event.js" type="text/javascript"></script>
# <script src="/site_media/yui/logger/logger-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/slider/slider-debug.js" type="text/javascript"></script>
# <script src="/site_media/yui/container/container-min.js" type="text/javascript"></script>
# <script src="/site_media/js/utils.js" type="text/javascript"></script>
# <script src="/site_media/js/cal.js" type="text/javascript"></script>
# <script src="http://www.google.com/jsapi?key=AIzaSyB_5kYKrWhW9DoJXnB5pjTprBlEk4LlkX0" type="text/javascript"></script>
# <script src="/site_media/js/map.js" type="text/javascript"></script>
# <script src="/site_media/js/results.js" type="text/javascript"></script>
# <title>Pet Friendly Hotels in New Haven, CT, US</title>
# <meta content="Pet friendly Hotels in New Haven, CT, US. Need help deciding where to stay? View pictures of each hotel, get the scoop on their pet policies, and read reviews of other guests with dogs here." name="description"/>
# <meta content="pet friendly lodging New Haven, pet friendly accommodations New Haven, pet friendly hotel New Haven" name="keywords"/>
# <script type="text/javascript">
# 	$(document).ready(function() {
#
#     $('#alert_close').click(function() {
#    $('#alert_wrapper').slideUp(200);
#    localStorage.call_042515_alert_status = 2;
#    return false;
# });
#
#     if(typeof(Storage)!=="undefined" && false) {
#         if (localStorage.call_042515_alert_status) {
#             if(localStorage.call_042515_alert_status == 1) $('#alert_wrapper').show();
#         } else {
#             setTimeout("$('#alert_wrapper').slideDown(300)", 1000);
#             localStorage.call_042515_alert_status = 1;
#         }
#     }
#
#
#
#
#
# 	});
# 	</script>
# </head>
# <body class="yui-skin-sam">
# <div id="alert_wrapper">
# <div id="alert_close"><a href="javascript:void(0);">×</a></div>
# <div id="alert">
# Our Pet Friendly Hotel Experts are available 24/7 to assist you at 877-411-3436
# </div>
# </div>
# <div id="main_wrapper">
# <div id="main">
# <div id="header">
# <div id="logo">
# <a href="/"><img alt="Bring Fido Logo" src="/site_media/images/bf_logo.gif"/></a>
# </div>
# <div id="call">
# <img alt="Speak to a Pet Friendly Travel Expert | 877-411-FIDO" src="/site_media/images/bf_call.gif"/>
# </div>
# <div id="header_nav">
# <ul>
# <li><a href="/destination/">DESTINATIONS</a></li>
# <li><a class="selected" href="/lodging/">LODGING</a></li>
# <li><a href="/travel/">AIR TRAVEL</a></li>
# <li><a href="/attraction/">ATTRACTIONS</a></li>
# <li><a href="/restaurant/">RESTAURANTS</a></li>
# <li><a href="/resource/">SERVICES</a></li>
# <li><a href="/event/">EVENTS</a></li>
# <li><a href="/photo/">PHOTOS</a></li>
# <li><a href="/forum/">FORUM</a></li>
# </ul>
# <div id="tab_left"></div>
# <div id="tab_right"></div>
# </div>
# </div>
# <div id="body">
# <div id="body_inner">
# <div id="panel" style="background-image:url('/site_media/images/panoramic/static/lodging.jpg');">
# <div id="content_wide">
# <div class="content_inner">
# <div id="breadcrumbs">
# <a href="/">Home</a> &gt; <a href="/lodging/">Accommodations</a>
# &gt; <a href="/lodging/region/united_states/">United States</a>
# &gt; <a href="/lodging/state/connecticut/">Connecticut</a>
# &gt; <a href="/lodging/city/new_haven_ct_us/">New Haven</a>
# </div>
# <div id="post_item">
# <img src="/site_media/images/pushpin.gif"/>
# <a href="/lodging/post/">Post a Property</a>
# </div>
# <div class="bottom_edge"></div>
# <div id="check_rates" style="font-family:sans-serif;">
# <div class="hd">Check Rates</div>
# <div class="bd">
# <form action="/lodging/check_rates/" method="POST" name="check_rates_form">
# <input name="hotel_id" type="hidden" value=""/>
# <div id="check_rates_form_contents"></div>
# </form>
# </div>
# </div>
# <script type="text/javascript">
# 		var check_rates_box = new YAHOO.widget.Dialog("check_rates",
# 					{ width : "325px",
# 					  fixedcenter : true,
# 					  zindex: 999,
# 					  modal: true,
# 					  draggable: false,
# 					  visible : false,
# 					  constraintoviewport : true,
# 					  hideaftersubmit : false
# 					 } );
# 		check_rates_box.render(document.body);
# 		check_rates_box.callback = {
# 			success : function(o) {
# 				var form_content = document.getElementById("check_rates_form_contents");
# 				if (o.responseText.search(/^\s*SUCCESS:\s*([^\s]+)\s*$/)>=0) {
# 					var next_page = RegExp.$1;
# 					form_content.innerHTML = "<span class='loading'>Loading...</span>"
# 					// alert("success! should now send user to booking page...");
# 					// document.location = next_page;
# 					window.open(next_page);
# 					check_rates_box.hide();
# 				}
# 				else {
# 					form_content.innerHTML = o.responseText;
# 					init_calendar_pair("id_arrival","cal_arrive_pop_box","Check-in Date",
# 									   "id_departure","cal_depart_pop_box","Check-out Date");
# 					check_rates_box.show();
# 				}
# 			},
# 			failure : function(o) {
# 				var form_content = document.getElementById("check_rates_form_contents");
# 				form_content.innerHTML = "Sorry. We could not complete your request due to technical issues. Please try again later.";
# 				check_rates_box.show();
# 			}
# 		}
#
# 		function check_rates(hid) {
# 			document.forms["check_rates_form"].action = "/lodging/check_rates/" + hid + "/";
# 			document.forms["check_rates_form"].hotel_id.value = hid;
# 			var form_content = document.getElementById("check_rates_form_contents");
# 			var callback = {
# 				success : function(o) {
# 					form_content.innerHTML = o.responseText;
# 					init_calendar_pair("id_arrival","cal_arrive_pop_box","Check-in Date",
# 									   "id_departure","cal_depart_pop_box","Check-out Date");
# 					check_rates_box.show();
# 				},
# 				failure : function(o) {
# 					form_content.innerHTML = "Sorry. The form could not be loaded. Please try again later.";
# 					check_rates_box.show();
# 				}
# 			}
# 			var conn = YAHOO.util.Connect.asyncRequest("GET", "/lodging/check_rates/" + hid + "/", callback);
# 		}
#
# 		function check_rates_submit() {
# 			check_rates_box.submit();
# 		}
# 	</script>
# <div id="results_header">
# <span class="title">Pet Friendly Hotels in New Haven, CT, US.</span><br/>
# Need help deciding where to stay in New Haven, CT, US?
# Use the links below to view pictures of each property, get the scoop on their pet policies,
# and read reviews of other guests with dogs. You can even check prices and availability online,
# or speak with a pet travel expert at 877-411-FIDO. And there are absolutely no booking fees!
# </div>
# <div class="detail_container">
# <div class="title">
# New Haven Pet Friendly Hotels
# <div class="title_controls">
# <form action="/quicksearch/lodging/" id="quick_search" method="get">
# Quick Search:
# <input class="bf_input cleardefault" default="Destination City" id="quick_search_loc" name="l" type="text"/>
# <input name="search" src="/site_media/images/go.gif" style="vertical-align:middle;" type="image"/>
# </form>
# </div>
# <div id="quick_search_feedback"></div>
# </div>
# <div id="quick_search_matches" style="width:200px;font-size:8pt;z-index:10;"></div>
# <script type="text/javascript">
# 			init_city_ac("quick_search_loc", "quick_search_matches", "quick_search_feedback", locationFeedbackHandler);
# 		</script>
# <div class="body" style="position:relative;padding:0;">
# <div id="map_canvas"></div>
# <div id="loading">Loading...</div>
# <div id="map_info" style="padding:10px;text-align:center;font-size:8pt;font-weight:bold;">
# <input id="map_control_attraction" style="vertical-align:middle;" type="checkbox"/> <img src="/site_media/images/icon_attraction.gif" style="vertical-align:middle;"/> Attractions
#
# <input id="map_control_restaurant" style="vertical-align:middle;" type="checkbox"/> <img src="/site_media/images/icon_restaurant.gif" style="vertical-align:middle;"/> Restaurants
#
# <input id="map_control_event" style="vertical-align:middle;" type="checkbox"/> <img src="/site_media/images/icon_event.gif" style="vertical-align:middle;"/> Events
#
# <input id="map_control_resource" style="vertical-align:middle;" type="checkbox"/> <img src="/site_media/images/icon_resource.gif" style="vertical-align:middle;"/> Resources
# </div>
# <div id="map_debug"></div>
# </div>
# </div>
# <div id="results_controls">
# <div id="results_sorting_controls" style="float:left;">
# <span style="font-weight:bold;padding-right:5px;">Sort by:</span>
# <span class="result_control" id="sort_name" onclick="resultsMgr.resort('name');">Name</span> |
# <span class="result_control" id="sort_price" onclick="resultsMgr.resort('price');">Price</span> |
# <span class="result_control" id="sort_popularity" onclick="resultsMgr.resort('popularity');">Popularity</span>
# </div>
# <div id="results_paging_controls_top" style="float:right;"></div>
# <div class="bottom_edge"></div>
# </div>
# <div id="results_map"></div>
# <div id="loading_hotels">
# <img src="/site_media/images/fetching.gif"/><br/>
# <img src="/site_media/images/loading_bar.gif"/>
# </div>
# <div id="results_list"></div>
# <div id="results_list_hidden" style="display:none;"></div>
# <div id="results_paging">
# <div id="results_paging_range_bottom" style="float:left;"></div>
# <div id="results_paging_controls_bottom" style="float:right;"></div>
# <div class="bottom_edge"></div>
# </div>
# <div class="detail_container nearby_results" style="padding-top:20px;">
# <div class="title">Dog Friendly Hotels in Surrounding Area</div>
# <div class="body">
# <ul class="links">
# <li><a href="/lodging/city/east_haven_ct_us">1 Pet Friendly Hotels in East Haven, CT, US</a> (3.7 miles from New Haven)</li>
# <li><a href="/lodging/city/north_haven_ct_us">1 Pet Friendly Hotels in North Haven, CT, US</a> (6.1 miles from New Haven)</li>
# <li><a href="/lodging/city/hamden_ct_us">2 Pet Friendly Hotels in Hamden, CT, US</a> (6.1 miles from New Haven)</li>
# <li><a href="/lodging/city/branford_ct_us">5 Pet Friendly Hotels in Branford, CT, US</a> (6.4 miles from New Haven)</li>
# <li><a href="/lodging/city/north-branford-ct-us">1 Pet Friendly Hotels in North Branford, CT, US</a> (8.6 miles from New Haven)</li>
# <li><a href="/lodging/city/milford_ct_us">7 Pet Friendly Hotels in Milford, CT, US</a> (8.9 miles from New Haven)</li>
# <li><a href="/lodging/city/shelton_ct_us">4 Pet Friendly Hotels in Shelton, CT, US</a> (10.6 miles from New Haven)</li>
# <li><a href="/lodging/city/wallingford_ct_us">1 Pet Friendly Hotels in Wallingford, CT, US</a> (11.5 miles from New Haven)</li>
# <li><a href="/lodging/city/stratford_ct_us">3 Pet Friendly Hotels in Stratford, CT, US</a> (12.7 miles from New Haven)</li>
# <li><a href="/lodging/city/guilford_ct_us">5 Pet Friendly Hotels in Guilford, CT, US</a> (12.9 miles from New Haven)</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div id="content_narrow">
# <div class="content_inner">
# <div class="search_container">
# <div class="search_border">
# <div class="search_box">
# <form action="/lodging/search/" id="tab_search" method="post">
# <div id="search_box_contents">
# </div>
# </form>
# </div>
# <script type="text/javascript">
#
#
# 		init_search_tabs(14745);
#
#
# 										</script>
# </div>
# </div>
# <div class="sidebar_container" id="refine_box">
# <div class="search_container">
# <div class="search_border">
# <div class="search_box">
# <div class="search_panel" style="display:block;">
# <h1>Refine Search (Optional)</h1>
# <form id="refine_form" name="refine_form">
# <div class="control">
# <label>Property Type:</label>
# <select name="type" onchange="resultsMgr.update_filter(this);">
# <option value="">All Property Types</option>
# <option value="H">Hotels &amp; Resorts</option>
# <option value="B">Bed &amp; Breakfasts</option>
# <option value="V">Vacation Rentals</option>
# <option value="A">Long-Term Apartments</option>
# <option value="C">Campgrounds</option>
# </select>
# </div>
# <div class="control">
# <label>Pet Policy:</label>
# <div class="row">
# <input class="check" name="no_fee" onclick="resultsMgr.update_filter(this);" type="checkbox"/> No Pet Fee or Deposit
# </div>
# <div class="row">
# <input class="check" name="deposit_only" onclick="resultsMgr.update_filter(this);" type="checkbox"/> Deposit Only; No Fee
# </div>
# <div class="row">
# <input class="check" name="fee_under_25" onclick="resultsMgr.update_filter(this);" type="checkbox"/> Pet Fee Less than $25
# </div>
# <div class="row">
# <input class="check" name="large_allowed" onclick="resultsMgr.update_filter(this);" type="checkbox"/> Big Dogs Allowed
# </div>
# <div class="row">
# <input class="check" name="multiple_allowed" onclick="resultsMgr.update_filter(this);" type="checkbox"/> Multiple Dogs Allowed
# </div>
# </div>
# <div class="control">
# <label>Average Guest Review:</label>
# <select name="fido_rating" onchange="resultsMgr.update_filter(this);">
# <option value="">Any Rating</option>
# <option value="5">5 Bones (highest)</option>
# <option value="4">4 Bones</option>
# <option value="3">3 Bones</option>
# <option value="2">2 Bones</option>
# <option value="1">1 Bone (lowest)</option>
# </select>
# </div>
# <div class="control">
# <label>Nightly Room Rate:</label>
# <div id="sliderbg">
# <div id="slider_thumb_min"></div>
# <div id="slider_thumb_max"></div>
# <span id="price_min">—</span>
# <span id="price_max">—</span>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="side_links">
# <div class="title">New Haven Quick Links</div>
# <div class="body">
# <div class="item_wrap">
# <div class="item">
# <a href="/destination/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Dog Owner's Guide</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a class="selected" href="/lodging/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Accommodations</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/lodging/hotels/city/new_haven_ct_us/">Hotels &amp; Motels (5)</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/lodging/post/">Post a New Property</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a href="/attraction/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Attractions</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/attraction/parks/city/new_haven_ct_us/">Dog Parks (2)</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/attraction/post/">Post a New Attraction</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a href="/restaurant/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Restaurants</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/restaurant/post/">Post a New Restaurant</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a href="/event/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Events</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/event/post/">Post a New Event</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a href="/resource/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Pet Services</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/resource/pet_sitters_dog_walkers/city/new_haven_ct_us/">Pet Sitting and Dog Walking (3)</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/resource/other_pet_services/city/new_haven_ct_us/">Other Pet Services (1)</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/resource/post/">Post a New Business</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a href="/photo/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Dog Pictures</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/photo/upload/city/new_haven_ct_us/">Post a New Photo</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a href="/forum/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Dog Forum</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/forum/city/new_haven_ct_us/">Post a New Topic</a>
# </div>
# </div>
# </div>
# </div>
# <div id="banner_ad_header">Local Sponsors</div>
# <div id="localresource_ads">
# <div class="localresource_ad">
# <a href="https://www.rover.com/new-haven--ct--dog-boarding/?utm_medium=online-directories&amp;utm_campaign=bringfido-ct-new-haven&amp;utm_source=bringfido.com&amp;utm_term=updated_042015" target="_blank">
# <img src="/site_media/resources/ROVER_logo.jpg"/>
# </a>
# </div>
# <div class="localresource_ad">
# <a href="https://dogvacay.com/dog-boarding--ct--new-haven?sid=003&amp;cid=072&amp;aid=044" target="_blank">
# <img src="/site_media/resources/Logo.jpg"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div id="bookmarks">
# <a href="javascript:window.print();"><img alt="Print" class="footer_action" src="/site_media/images/print.gif"/></a>
# <div class="footer_separator"></div>
# <a href="/promo/tellafriend/five_bucks/"><img alt="Tell a Friend" class="footer_action" src="/site_media/images/email.gif"/></a>
# <div class="footer_separator"></div>
# <form action="/signup/" id="signup" method="get">
# Free Pet Samples &amp; Travel Discounts
# <input class="bf_input cleardefault" default="Email Address" name="email" style="vertical-align:middle;padding:2px;width:120px;" type="text"/>
# <input name="signup" src="/site_media/images/signup.gif" style="vertical-align:middle;" type="image"/>
# </form>
# <a href="http://twitter.com/BringFido" target="_blank"><img alt="Follow us on Twitter" class="footer_action_large" src="/site_media/images/twitter.gif"/></a>
# <a href="http://www.facebook.com/pages/BringFidocom/92703702876?ref=s" target="_blank"><img alt="Follow us on Facebook" class="footer_action_large" src="/site_media/images/facebook.gif"/></a>
# <a href="https://plus.google.com/117673165909068565296" rel="publisher" target="_blank"><img alt="Find us on Google+" class="footer_action_large" src="/site_media/images/googleplus.gif"/></a>
# <div class="bottom_edge"></div>
# </div>
# </div>
# </div>
# <div id="bottom_edge"></div>
# </div>
# <div id="footer">
# <div id="footer_nav">
# <p>
# <a href="/about/">About Us</a>
# | <a href="/help/">Customer Service</a>
# | <a href="/contact/">Contact Us</a>
# | <a href="/advertise/">Advertising</a>
# | <a href="/affiliate/petcharity/">Pet Charities</a>
# | <a href="/affiliate/">Affiliates</a>
# | <a href="/press/">Media</a>
# | <a href="/affiliate/link/">Link to Us</a>
# | <a href="/resource/online_resources/">Sites We Like</a>
# | <a href="/sitemap/">Site Map</a>
# | <a href="/privacy/">Privacy Policy</a>
# | <a href="/terms/">Terms &amp; Conditions</a>
# </p>
# <p>
# © 2005-2015 Kendall Media, Inc.<br/>
# BringFido.com is a trademark of Kendall Media, Inc.
# </p>
# <p>PO Box 1489 | Travelers Rest, SC 29690 | (877) 411-3436</p>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
#
# 		load_hotel_search(14745);
#
#
# 	</script>
# <script type="text/javascript">
# <!--
# 	google.load("maps", "2.x");
# 	var resultsMgr = new HotelResultsManager(15,'popularity');
# 	resultsMgr.addLoadingPanel('loading');
# 	resultsMgr.addLoadingPanel('loading_hotels');
#
# 	function initialize() {
# 		var map = new google.maps.Map2(document.getElementById("map_canvas"));
# 		var location = new GLatLng(41.311053, -72.930416);
# 		map.setCenter(location, 11);
# 		map.addControl(new GLargeMapControl3D());
# 		map.addControl(new GScaleControl());
# 		init_map_controls(map, {}, {}, {});
#
# 		var advanced_options = {};
#
#
# 		resultsMgr.attachMap(map);
# 		resultsMgr.init_results('cid=14745&ar=&dt=&rm=1&ad=1&ch=0&dg=1',
# 								null,
# 								null,'',advanced_options);
#
# 		GEvent.addListener(map, "dragend", function() {
# 			resultsMgr.init_map_results('cid=14745&ar=&dt=&rm=1&ad=1&ch=0&dg=1',
# 										null,
# 										map,null,null,'');
# 		});
# 	}
# 	google.setOnLoadCallback(initialize);
# 	// YAHOO.util.Event.onDOMReady(initialize);
# //-->
# </script>
# </div>
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-88624-2']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
# </body>
# </html>

# %%
url_quinta = "http://www.bringfido.com/lodging/70449/?cid=14745&ar=&dt=&rm=1&ad=1&ch=0&dg=1&rt=75.01"

# %%
q = Request(url_quinta)
q.add_header('User-Agent', 'Mozilla/5.0')
page = urlopen(q).read()

# %%
soup = BeautifulSoup(page)

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/site_media/css/screen.css" rel="stylesheet" type="text/css"/>
# <meta content="app-id=682820712" name="apple-itunes-app"/>
# <link href="/site_media/yui/container/assets/skins/sam/container.css" rel="stylesheet" type="text/css"/>
# <link href="/site_media/yui/calendar/assets/skins/sam/calendar.css" rel="stylesheet" type="text/css"/>
# <link href="/site_media/yui/autocomplete/assets/skins/sam/autocomplete.css" rel="stylesheet" type="text/css"/>
# <link href="/site_media/images/favicon.ico" rel="icon" type="image/png"/>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.8.3/jquery.min.js" type="text/javascript"></script>
# <script src="/site_media/yui/yahoo-dom-event/yahoo-dom-event.js" type="text/javascript"></script>
# <script src="/site_media/yui/connection/connection-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/container/container-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/calendar/calendar-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/autocomplete/autocomplete-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/dragdrop/dragdrop-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/slider/slider-min.js" type="text/javascript"></script>
# <script src="/site_media/js/utils.js" type="text/javascript"></script>
# <script src="/site_media/js/autocomplete.js" type="text/javascript"></script>
# <script src="/site_media/js/cal.js" type="text/javascript"></script>
# <script src="/site_media/js/tab_search.js" type="text/javascript"></script>
# <script src="/site_media/js/default_text.js" type="text/javascript"></script>
# <script src="/site_media/js/alert.js" type="text/javascript"></script>
# <script src="/site_media/yui/yahoo/yahoo-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/json/json-min.js" type="text/javascript"></script>
# <script src="/site_media/yui/container/container-min.js" type="text/javascript"></script>
# <script src="/site_media/js/utils.js" type="text/javascript"></script>
# <script src="/site_media/js/cal.js" type="text/javascript"></script>
# <script src="http://www.google.com/jsapi?key=AIzaSyB_5kYKrWhW9DoJXnB5pjTprBlEk4LlkX0" type="text/javascript"></script>
# <script src="/site_media/js/map.js" type="text/javascript"></script>
# <title>La Quinta Inn &amp; Suites New Haven Pet Policy</title>
# <meta content="La Quinta Inn &amp; Suites New Haven, La Quinta Inn &amp; Suites New Haven pet policy, La Quinta Inn &amp; Suites New Haven dog friendly, La Quinta Inn &amp; Suites New Haven pet friendly, pet friendly hotel New Haven, dog friendly hotel New Haven" name="keywords"/>
# <script type="text/javascript">
# 	$(document).ready(function() {
#
#     $('#alert_close').click(function() {
#    $('#alert_wrapper').slideUp(200);
#    localStorage.call_042515_alert_status = 2;
#    return false;
# });
#
#     if(typeof(Storage)!=="undefined" && false) {
#         if (localStorage.call_042515_alert_status) {
#             if(localStorage.call_042515_alert_status == 1) $('#alert_wrapper').show();
#         } else {
#             setTimeout("$('#alert_wrapper').slideDown(300)", 1000);
#             localStorage.call_042515_alert_status = 1;
#         }
#     }
#
#
#
#
#
# 	});
# 	</script>
# </head>
# <body class="yui-skin-sam">
# <div id="alert_wrapper">
# <div id="alert_close"><a href="javascript:void(0);">×</a></div>
# <div id="alert">
# Our Pet Friendly Hotel Experts are available 24/7 to assist you at 877-411-3436
# </div>
# </div>
# <div id="main_wrapper">
# <div id="main">
# <div id="header">
# <div id="logo">
# <a href="/"><img alt="Bring Fido Logo" src="/site_media/images/bf_logo.gif"/></a>
# </div>
# <div id="call">
# <img alt="Speak to a Pet Friendly Travel Expert | 877-411-FIDO" src="/site_media/images/bf_call.gif"/>
# </div>
# <div id="header_nav">
# <ul>
# <li><a href="/destination/">DESTINATIONS</a></li>
# <li><a class="selected" href="/lodging/">LODGING</a></li>
# <li><a href="/travel/">AIR TRAVEL</a></li>
# <li><a href="/attraction/">ATTRACTIONS</a></li>
# <li><a href="/restaurant/">RESTAURANTS</a></li>
# <li><a href="/resource/">SERVICES</a></li>
# <li><a href="/event/">EVENTS</a></li>
# <li><a href="/photo/">PHOTOS</a></li>
# <li><a href="/forum/">FORUM</a></li>
# </ul>
# <div id="tab_left"></div>
# <div id="tab_right"></div>
# </div>
# </div>
# <div id="body">
# <div id="body_inner">
# <div id="panel" style="background-image:url('/site_media/images/panoramic/static/lodging_hotels.jpg');">
# <div id="content_wide">
# <div class="content_inner">
# <div id="breadcrumbs">
# <a href="/">Home</a> &gt; <a href="/lodging/">Accommodations</a>
# &gt; <a href="/lodging/region/united_states/">United States</a>
# &gt; <a href="/lodging/state/connecticut/">Connecticut</a>
# &gt; <a href="/lodging/city/new_haven_ct_us/">New Haven</a>
# &gt; <a href="/lodging/70449/">La Quinta Inn &amp; Suites New Haven</a>
# </div>
# <div id="post_item"></div>
# <div class="bottom_edge"></div>
# <div id="check_rates" style="font-family:sans-serif;">
# <div class="hd">Check Rates</div>
# <div class="bd">
# <form action="/lodging/check_rates/" method="POST" name="check_rates_form"><input name="hotel_id" type="hidden" value=""/><div id="check_rates_form_contents"></div>
# </form>
# </div>
# </div>
# <script type="text/javascript">
# 		var check_rates_box = new YAHOO.widget.Dialog("check_rates",
# 					{ width : "325px",
# 					  fixedcenter : true,
# 					  zindex: 999,
# 					  modal: true,
# 					  draggable: false,
# 					  visible : false,
# 					  constraintoviewport : true,
# 					  hideaftersubmit : false
# 					 } );
# 		check_rates_box.render(document.body);
# 		check_rates_box.callback = {
# 			success : function(o) {
# 				var form_content = document.getElementById("check_rates_form_contents");
# 				if (o.responseText.search(/^\s*SUCCESS:\s*([^\s]+)\s*$/)>=0) {
# 					var next_page = RegExp.$1;
# 					form_content.innerHTML = "<span class='loading'>Loading...</span>"
# 					// alert("success! should now send user to booking page...");
# 					document.location = next_page;
# 				}
# 				else {
# 					form_content.innerHTML = o.responseText;
# 					check_rates_box.show();
# 				}
# 			},
# 			failure : function(o) {
# 				var form_content = document.getElementById("check_rates_form_contents");
# 				form_content.innerHTML = "Sorry. We could not complete your request due to technical issues. Please try again later.";
# 				check_rates_box.show();
# 			}
# 		}
#
# 		function check_rates(hid) {
# 			document.forms["check_rates_form"].action = "/lodging/check_rates/" + hid + "/";
# 			document.forms["check_rates_form"].hotel_id.value = hid;
# 			var form_content = document.getElementById("check_rates_form_contents");
# 			var callback = {
# 				success : function(o) {
# 					form_content.innerHTML = o.responseText;
# 					init_calendar_pair("id_arrival","cal_arrive_pop_box","Check-in Date",
# 									   "id_departure","cal_depart_pop_box","Check-out Date");
# 					check_rates_box.show();
# 				},
# 				failure : function(o) {
# 					form_content.innerHTML = "Sorry. The form could not be loaded. Please try again later.";
# 					check_rates_box.show();
# 				}
# 			}
# 			var conn = YAHOO.util.Connect.asyncRequest("GET", "/lodging/check_rates/" + hid + "/", callback);
# 		}
#
# 		function check_rates_submit() {
# 			check_rates_box.submit();
# 		}
# 	</script>
# <div id="update_policy" style="font-family:sans-serif;">
# <div class="hd">Update Pet Policy</div>
# <div class="bd">
# <form action="/lodging/update_policy/" method="POST" name="update_policy_form"><input name="hotel_id" type="hidden" value=""/><div id="update_policy_form_contents"></div>
# </form>
# </div>
# </div>
# <script type="text/javascript">
# 		var update_policy_box = new YAHOO.widget.Dialog("update_policy",
# 					{ width : "500px",
# 					  fixedcenter : true,
# 					  zindex: 999,
# 					  modal: true,
# 					  draggable: false,
# 					  visible : false,
# 					  constraintoviewport : true,
# 					  hideaftersubmit : false
# 					 } );
# 		update_policy_box.render(document.body);
# 		update_policy_box.callback = {
# 			success : function(o) {
# 				var form_content = document.getElementById("update_policy_form_contents");
# 				if (o.responseText.search(/^\s*SUCCESS:\s*([^\s]+)\s*$/)>=0) {
# 					var next_page = RegExp.$1;
# 					form_content.innerHTML = "<span class='loading'>Saving...</span>"
# 					// alert("success! should now send user to booking page...");
# 					window.location.reload();
# 					update_policy_box.hide();
# 				}
# 				else {
# 					form_content.innerHTML = o.responseText;
# 					update_policy_box.show();
# 				}
# 			},
# 			failure : function(o) {
# 				var form_content = document.getElementById("update_policy_form_contents");
# 				form_content.innerHTML = "Sorry. We could not complete your request due to technical issues. Please try again later.";
# 				update_policy_box.show();
# 			}
# 		}
#
# 		function update_policy(hid) {
# 			document.forms["update_policy_form"].action = "/lodging/update_policy/" + hid + "/";
# 			document.forms["update_policy_form"].hotel_id.value = hid;
# 			var form_content = document.getElementById("update_policy_form_contents");
# 			var callback = {
# 				success : function(o) {
# 					form_content.innerHTML = o.responseText;
# 					update_policy_box.show();
# 				},
# 				failure : function(o) {
# 					form_content.innerHTML = "Sorry. The form could not be loaded. Please try again later.";
# 					update_policy_box.show();
# 				}
# 			}
# 			var conn = YAHOO.util.Connect.asyncRequest("GET", "/lodging/update_policy/" + hid + "/", callback);
# 		}
#
# 		function update_policy_submit() {
# 			update_policy_box.submit();
# 		}
# 		function update_policy_cancel() {
# 			update_policy_box.cancel();
# 		}
#
#
# 	</script>
# <div id="detail_header" style="color:#000;">
# <div class="info">
# <div class="title">
# <a class="anchor" name="overview">La Quinta Inn &amp; Suites New Haven</a>
# <a href="#reviews">
# <img src="/site_media/images/4bones.gif" style="vertical-align:middle;"/>
# </a>
# </div>
# <div class="address">
# 400 Sargent Dr<br/>
# New Haven, CT, US 06511-5907<br/>
# 877-411-3436<br/>
# <a href="http://www.lq.com/en/findandbook/hotel-details.2048.address.html?IATA=99020592&amp;cid=BRAND_BRINGFIDO" target="_blank">View Website</a><br/>
# </div>
# <div class="rate_info">
# <a class="big_button" href="#" onclick="check_rates(70449);">CHECK RATES</a>
# <div class="rate_wrap">
# Low Rates from<br/>
# <span class="nightly_rate">$75</span>
# (no pet fee)
# </div>
# <a onclick="popout('/lowrate',500,500);"><img alt="blue ribbon guarantee" src="/site_media/images/blueribbon.jpg" style="vertical-align:top;"/></a>
# </div>
# </div>
# <div class="map">
# <a href="#map"><img src="http://maps.googleapis.com/maps/api/staticmap?center=41.295101166,-72.9190979&amp;zoom=15&amp;size=280x150&amp;sensor=false&amp;markers=color:blue%7C41.295101166,-72.9190979&amp;key=AIzaSyB_5kYKrWhW9DoJXnB5pjTprBlEk4LlkX0"/></a>
# <a class="normal" href="#map">View Large Map</a>
# </div>
# <div class="bottom_edge"></div>
# </div>
# <div class="detail_container">
# <div class="title">La Quinta Inn &amp; Suites New Haven Pet Policy</div>
# <div class="body">
# La Quinta Inn &amp; Suites New Haven is pet friendly! Up to two pets of any size are allowed in each room for no additional fee or deposit.
# If you find that this pet policy is no longer accurate, please <a class="links" href="#" onclick="update_policy(70449);">submit a correction</a> now.
#
# </div>
# </div>
# <div class="detail_container">
# <div class="title"><a class="anchor" name="photos">Photos of La Quinta Inn &amp; Suites New Haven</a></div>
# <div class="body">
# <script type="text/javascript">
# 					var loaded_photo_id = undefined;
# 					function load_photo(id) {
# 						if (loaded_photo_id != id) {
# 							YAHOO.util.Dom.setStyle(loaded_photo_id, "display", "none");
# 							YAHOO.util.Dom.setStyle(id, "display", "block");
# 							loaded_photo_id = id;
# 						}
# 					}
# 				</script>
# <div id="photo_large">
# <img class="photo" id="photo_1165765" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_60_b.jpg"/>
# <img class="photo" id="photo_3402968" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_64_b.jpg"/>
# <img class="photo" id="photo_3402967" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_63_b.jpg"/>
# <img class="photo" id="photo_3402966" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_56_b.jpg"/>
# <img class="photo" id="photo_3402965" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_54_b.jpg"/>
# <img class="photo" id="photo_3402964" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_50_b.jpg"/>
# <img class="photo" id="photo_3402963" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_45_b.jpg"/>
# <img class="photo" id="photo_3402962" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_44_b.jpg"/>
# </div>
# <div id="photo_thumbs">
# <div class="thumb_box">
# <img class="thumb" id="thumb_1165765" onclick="load_photo('photo_1165765');" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_60_b.jpg"/>
# </div>
# <div class="thumb_box">
# <img class="thumb" id="thumb_3402968" onclick="load_photo('photo_3402968');" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_64_b.jpg"/>
# </div>
# <div class="thumb_box">
# <img class="thumb" id="thumb_3402967" onclick="load_photo('photo_3402967');" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_63_b.jpg"/>
# </div>
# <div class="thumb_box">
# <img class="thumb" id="thumb_3402966" onclick="load_photo('photo_3402966');" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_56_b.jpg"/>
# </div>
# <div class="thumb_box">
# <img class="thumb" id="thumb_3402965" onclick="load_photo('photo_3402965');" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_54_b.jpg"/>
# </div>
# <div class="thumb_box">
# <img class="thumb" id="thumb_3402964" onclick="load_photo('photo_3402964');" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_50_b.jpg"/>
# </div>
# <div class="thumb_box">
# <img class="thumb" id="thumb_3402963" onclick="load_photo('photo_3402963');" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_45_b.jpg"/>
# </div>
# <div class="thumb_box">
# <img class="thumb" id="thumb_3402962" onclick="load_photo('photo_3402962');" src="http://www.bringfido.com/site_media/photos/ein/4/8/2/184284/1241_44_b.jpg"/>
# </div>
# <div class="bottom_edge"></div>
# <div style="text-align:right;">
# <a href="/photo/upload/hotel/70449" style="color:#BC9C66;">
# <img src="/site_media/images/camera_icon.gif" style="padding:10px 25px 0 0;"/><br/>Post a Photo
# </a>
# </div>
# </div>
# <script type="text/javascript">
# 					var photos = document.getElementById('photo_large').getElementsByTagName('img');
# 					if (photos.length > 0) {
# 						// alert(photos[0].id);
# 						load_photo(photos[0].id);
# 					}
# 				</script>
# <div class="bottom_edge"></div>
# </div>
# </div>
# <div class="detail_container">
# <div class="title">Description of La Quinta Inn &amp; Suites New Haven</div>
# <div class="body">
# The newly renovated La Quinta Inn &amp; Suites New Haven features all-new guest rooms, Free Bright Side Breakfast, a fitness center, restaurant/bar, and local transportation within a 5-mile radius! From its convenient location at the I-95 and I-91 junction near downtown, the La Quinta Inn &amp; Suites New Haven is the perfect hotel for those visiting Yale University or University of New Haven. The Long Wharf, featuring the Amistad Tallship and Maritime Center and Shubert Theater (1 mile away) are also easily accessible from this hotel. Enjoy stunning views of the Long Island Sound and easy access to major companies such as Assa Abloy, Sargent, Bayer, and Subway. Dine at the Greek Olive Restaurant (adjoined to the hotel), or select from several other local favorites including Sage, Brazis Italian Bistro, or the Leon's . Shop at nearby IKEA, or visit the shops of downtown just minutes from the hotel. In addition to free wireless high-speed Internet access, each spacious room includes a well-lit work desk, coffee maker, 25-inch TV w/cable and movies, hair dryer, and much more. This New Haven hotel also offers a sparkling outdoor swimming pool, fitness center, and coin-operated laundry facilities.
# </div>
# </div>
# <div class="detail_container">
# <div class="title">Amenities Available at La Quinta Inn &amp; Suites New Haven</div>
# <div class="body amenities">
# <ul>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Restaurant
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Room service
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Non-smoking rooms
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Fitness center
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Business center
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Data port
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Dry cleaning/laundry
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Meeting rooms
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Pets accepted
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Wheelchair accessible
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Swimming pool
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Airport shuttle
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Family Rooms
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Free breakfast
# </li>
# <li>
# <img src="/site_media/images/wedge.gif"/>
# Free high-speed internet
# </li>
# </ul>
# <div class="bottom_edge"></div>
# </div>
# </div>
# <div id="submit_review" style="font-family:sans-serif;">
# <div class="hd">Submit a Review</div>
# <div class="bd">
# <form action="/lodging/submit_review/" method="POST" name="submit_review_form"><input name="hotel" type="hidden" value=""/><div id="submit_review_form_contents"></div>
# </form>
# </div>
# </div>
# <script type="text/javascript">
# 		var submit_review_box = new YAHOO.widget.Dialog("submit_review",
# 					{ width : "450px",
# 					  fixedcenter : true,
# 					  zindex: 999,
# 					  modal: true,
# 					  draggable: false,
# 					  visible : false,
# 					  constraintoviewport : true,
# 					  hideaftersubmit : false
# 					 } );
# 		submit_review_box.render(document.body);
# 		submit_review_box.callback = {
# 			success : function(o) {
# 				var form_content = document.getElementById("submit_review_form_contents");
# 				if (o.responseText.search(/^\s*SUCCESS:\s*([^\s]+)\s*$/)>=0) {
# 					var next_page = RegExp.$1;
# 					form_content.innerHTML = "<span class='loading'>Saving...</span>"
# 					// alert("success! just hide form now...");
# 					window.location.reload();
# 					submit_review_box.hide();
# 				}
# 				else {
# 					form_content.innerHTML = o.responseText;
# 					submit_review_box.show();
# 				}
# 			},
# 			failure : function(o) {
# 				var form_content = document.getElementById("submit_review_form_contents");
# 				form_content.innerHTML = "Sorry. We could not save your review due to technical issues. Please try again later.";
# 				submit_review_box.show();
# 			}
# 		}
#
# 		function submit_review(hid) {
# 			document.forms["submit_review_form"].action = "/lodging/submit_review/" + hid + "/";
# 			document.forms["submit_review_form"].hotel.value = hid;
# 			var form_content = document.getElementById("submit_review_form_contents");
# 			var callback = {
# 				success : function(o) {
# 					form_content.innerHTML = o.responseText;
# 					submit_review_box.show();
# 				},
# 				failure : function(o) {
# 					form_content.innerHTML = "Sorry. The form could not be loaded. Please try again later.";
# 					submit_review_box.show();
# 				}
# 			}
# 			var conn = YAHOO.util.Connect.asyncRequest("GET", "/lodging/submit_review/" + hid + "/", callback);
# 		}
#
# 		function submit_review_submit() {
# 			submit_review_box.submit();
# 		}
#
# 		function submit_review_cancel() {
# 			submit_review_box.cancel();
# 		}
# 	</script>
# <div class="detail_container">
# <div class="title"><a class="anchor" name="reviews">Guest Reviews of La Quinta Inn &amp; Suites New Haven</a></div>
# <div class="body">
# <div class="review_header">
# <div>
# <span style="vertical-align:top;">Average Rating:</span>
# <img src="/site_media/images/4bones.gif"/>
# </div>
# La Quinta Inn &amp; Suites New Haven in New Haven, CT, US has an average rating of 4.0
# based on 2 guest reviews.
# <div class="bottom_edge"></div>
# </div>
# <div class="review_list_container">
# <div>
# <div class="review_text" style="padding-top:0;padding-bottom:0;">Review</div>
# <div class="rating_text" style="padding-top:0;padding-bottom:0;">Rating</div>
# <div class="bottom_edge"></div>
# </div>
# <div class="review_container_outer">
# <div class="review_container">
# <div class="review_text">
# <div style="font-weight:bold;">Great value and no pet fee</div>
# <div>
# Erin
# in Washington, DC
# </div>
# <div style="padding-top:5px;">My 75lb dog and I received a lovely welcome from two young gentlemen working at the desk the evening of 8/1/14. Check-in was very easy and even though this hotel is close to the highway and Ikea, there is a big patch of grass/bushes out front for dogs to relieve themselves --I didn't see bags so bring your own. Yes, I agree with review that it is an older place but my room with one queen bed was plenty clean and comfortable. When I travel with my dog, the less fancy the better. :). Also, it made it nice that there was a dog friendly restaurant less than 10 minute drive away...see review for "Basta". I definitely feel good about spending just over $100 at this hotel which was just a stop along the way in my travels. Recommend to other dog owners. (P.s. This site says small pets only but that is not up to date. The policy attached on this site shows that they take any size). </div>
# </div>
# <div class="rating_text">
# <img src="/site_media/images/5bones.gif"/>
# </div>
# <div class="bottom_edge"> </div>
# </div>
# </div>
# <div class="review_container_outer">
# <div class="review_container">
# <div class="review_text">
# <div style="font-weight:bold;">Getting old</div>
# <div>
# Lawrence
# in Pittsfield, MA
# </div>
# <div style="padding-top:5px;">I stayed at this La Quinta and felt that it was getting up there in age and a little run down. It was decently clean, although not fully clean. The staff were fairly helpful.</div>
# </div>
# <div class="rating_text">
# <img src="/site_media/images/3bones.gif"/>
# </div>
# <div class="bottom_edge"> </div>
# </div>
# </div>
# <div style="padding-top:5px;padding-right:10px;">
# <div style="float:right;"><a class="button" href="#reviews" onclick="submit_review(70449);">ADD REVIEW</a></div>
# <div class="bottom_edge"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="detail_container">
# <div class="title"><a class="anchor" name="map">Area Map</a></div>
# <div class="body" style="padding:0;position:relative;">
# <div id="map_canvas"></div>
# <div id="loading">Loading...</div>
# <div id="map_info" style="padding:10px 0;text-align:center;font-size:8pt;font-weight:bold;">
# <input id="map_control_lodging" style="vertical-align:middle;" type="checkbox"/> <img src="/site_media/images/icon_hotel.gif" style="vertical-align:middle;"/> Hotels
#
# <input id="map_control_attraction" style="vertical-align:middle;" type="checkbox"/> <img src="/site_media/images/icon_attraction.gif" style="vertical-align:middle;"/> Attractions
#
# <input id="map_control_restaurant" style="vertical-align:middle;" type="checkbox"/> <img src="/site_media/images/icon_restaurant.gif" style="vertical-align:middle;"/> Restaurants
#
# <input id="map_control_event" style="vertical-align:middle;" type="checkbox"/> <img src="/site_media/images/icon_event.gif" style="vertical-align:middle;"/> Events
#
# <input id="map_control_resource" style="vertical-align:middle;" type="checkbox"/> <img src="/site_media/images/icon_resource.gif" style="vertical-align:middle;"/> Resources
# </div>
# <div id="map_debug"></div>
# <script type="text/javascript">
# 				google.load("maps", "2.x");
#
# 				function initialize() {
# 					var map = new google.maps.Map2(document.getElementById("map_canvas"));
# 					var location = new GLatLng(41.295101166, -72.9190979);
# 					map.setCenter(location, 15);
# 					map.addControl(new GLargeMapControl3D());
# 					map.addControl(new GScaleControl());
# 					init_map_controls(map, {'lodging':{ 70449:true }}, {}, {'lodging':true});
# 				}
# 				google.setOnLoadCallback(initialize);
# 			</script>
# </div>
# </div>
# <div class="detail_container">
# <div class="title">Reserve a Room at La Quinta Inn &amp; Suites New Haven</div>
# <div class="body">
# To reserve a room at La Quinta Inn &amp; Suites New Haven, please click the button below, or call 877-411-3436 to speak with a
# pet travel expert. There are no fees for booking on BringFido.com and we guarantee the best rates available online. Still
# trying to decide? We can also provide you with information on all <a href="/lodging/city/new_haven_ct_us/">pet friendly hotels in New Haven</a> here.
# <div class="rate_info">
# <a class="big_button" href="#" onclick="check_rates(70449);">CHECK RATES</a>
# <div class="rate_wrap">
# Low Rates from<br/>
# <span class="nightly_rate">$75</span>
# (no pet fee)
# </div>
# <a onclick="popout('/lowrate',500,500);"><img alt="blue ribbon guarantee" src="/site_media/images/blueribbon.jpg" style="vertical-align:top;"/></a>
# </div>
# <div class="bottom_edge"></div>
# </div>
# </div>
# </div>
# </div>
# <div id="content_narrow">
# <div class="content_inner">
# <div class="search_container">
# <div class="search_border">
# <div class="search_box">
# <form action="/lodging/search/" id="tab_search" method="post">
# <div id="search_box_contents">
# </div>
# </form>
# </div>
# <script type="text/javascript">
#
# 	// H
#
#
# 			init_search_tabs(14745);
#
#
#
# 										</script>
# </div>
# </div>
# <div class="side_links">
# <div class="title">New Haven Quick Links</div>
# <div class="body">
# <div class="item_wrap">
# <div class="item">
# <a href="/destination/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Dog Owner's Guide</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a href="/lodging/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Accommodations</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/lodging/hotels/city/new_haven_ct_us/">Hotels &amp; Motels (5)</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/lodging/post/">Post a New Property</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a href="/attraction/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Attractions</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/attraction/parks/city/new_haven_ct_us/">Dog Parks (2)</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/attraction/post/">Post a New Attraction</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a href="/restaurant/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Restaurants</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/restaurant/post/">Post a New Restaurant</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a href="/event/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Events</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/event/post/">Post a New Event</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a href="/resource/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Pet Services</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/resource/pet_sitters_dog_walkers/city/new_haven_ct_us/">Pet Sitting and Dog Walking (3)</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/resource/other_pet_services/city/new_haven_ct_us/">Other Pet Services (1)</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/resource/post/">Post a New Business</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a href="/photo/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Dog Pictures</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/photo/upload/city/new_haven_ct_us/">Post a New Photo</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <a href="/forum/city/new_haven_ct_us/" style="font-weight:bold;">New Haven Dog Forum</a>
# </div>
# </div>
# <div class="item_wrap">
# <div class="item">
# <img class="bullet" src="/site_media/images/wedge.gif"/>
# <a href="/forum/city/new_haven_ct_us/">Post a New Topic</a>
# </div>
# </div>
# </div>
# </div>
# <div id="banner_ad_header">Local Sponsors</div>
# <div id="localresource_ads">
# <div class="localresource_ad">
# <a href="https://www.rover.com/new-haven--ct--dog-boarding/?utm_medium=online-directories&amp;utm_campaign=bringfido-ct-new-haven&amp;utm_source=bringfido.com&amp;utm_term=updated_042015" target="_blank">
# <img src="/site_media/resources/ROVER_logo.jpg"/>
# </a>
# </div>
# <div class="localresource_ad">
# <a href="https://dogvacay.com/dog-boarding--ct--new-haven?sid=003&amp;cid=072&amp;aid=044" target="_blank">
# <img src="/site_media/resources/Logo.jpg"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div id="bookmarks">
# <a href="javascript:window.print();"><img alt="Print" class="footer_action" src="/site_media/images/print.gif"/></a>
# <div class="footer_separator"></div>
# <a href="/promo/tellafriend/five_bucks/"><img alt="Tell a Friend" class="footer_action" src="/site_media/images/email.gif"/></a>
# <div class="footer_separator"></div>
# <form action="/signup/" id="signup" method="get">
# Free Pet Samples &amp; Travel Discounts
# <input class="bf_input cleardefault" default="Email Address" name="email" style="vertical-align:middle;padding:2px;width:120px;" type="text"/>
# <input name="signup" src="/site_media/images/signup.gif" style="vertical-align:middle;" type="image"/>
# </form>
# <a href="http://twitter.com/BringFido" target="_blank"><img alt="Follow us on Twitter" class="footer_action_large" src="/site_media/images/twitter.gif"/></a>
# <a href="http://www.facebook.com/pages/BringFidocom/92703702876?ref=s" target="_blank"><img alt="Follow us on Facebook" class="footer_action_large" src="/site_media/images/facebook.gif"/></a>
# <a href="https://plus.google.com/117673165909068565296" rel="publisher" target="_blank"><img alt="Find us on Google+" class="footer_action_large" src="/site_media/images/googleplus.gif"/></a>
# <div class="bottom_edge"></div>
# </div>
# </div>
# </div>
# <div id="bottom_edge"></div>
# </div>
# <div id="footer">
# <div id="footer_nav">
# <p>
# <a href="/about/">About Us</a>
# | <a href="/help/">Customer Service</a>
# | <a href="/contact/">Contact Us</a>
# | <a href="/advertise/">Advertising</a>
# | <a href="/affiliate/petcharity/">Pet Charities</a>
# | <a href="/affiliate/">Affiliates</a>
# | <a href="/press/">Media</a>
# | <a href="/affiliate/link/">Link to Us</a>
# | <a href="/resource/online_resources/">Sites We Like</a>
# | <a href="/sitemap/">Site Map</a>
# | <a href="/privacy/">Privacy Policy</a>
# | <a href="/terms/">Terms &amp; Conditions</a>
# </p>
# <p>
# © 2005-2015 Kendall Media, Inc.<br/>
# BringFido.com is a trademark of Kendall Media, Inc.
# </p>
# <p>PO Box 1489 | Travelers Rest, SC 29690 | (877) 411-3436</p>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# 	// H
#
#
# 			load_hotel_search(14745);
#
#
#
# 	</script>
# </div>
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-88624-2']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
# </body>
# </html>
